# %%
import cv2
import numpy as np
cap = cv2.VideoCapture(0)
while True:
    ret, frame = cap.read() 
    roi = frame[269:795,437:1416]
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    _, threshold = cv2.threshold(gray,37,255,cv2.THRESH_BINARY_INV)
    roiThreshold= threshold[269:795,437:1416]
    show=cv2.GaussianBlur(threshold[269:795,437:1416],(7,7),0)
    contours,_ = cv2.findContours(show,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)#RETR_TREE는 모두 검출함
    
    contours = sorted(contours, key=lambda x:cv2.contourArea(x), reverse = True)
    if ret:
        rows,cols,_ = roi.shape
        
        #print(len(contours))
        #print(contours)# 리스트의 원소의 갯수는 컨투어의 갯수와 같다.컨투어 정보는 컨투어를 구성하는 점들로 이루어진 배열의 리스트다.
        
        for cnt in contours:
            
            (x,y,w,h) = cv2.boundingRect(cnt)
            
            cv2.drawContours(roi,[cnt],-1,(0,0,255),1)
            cv2.rectangle(roi,(x,y),(x+w,y+h),(255,0,0),1)
            
            #사각형이 너무 많이 잡힘. 가장 큰 사각형만 추출 할 수 있으면,,
            
            cv2.line(roi,(x+int(w/2),0),(x+int(w/2),rows),(0,255,0),2)
            cv2.line(roi,(0,y+int(h/2)),(cols, y+int(h/2)),(0,255,0),2)
            
        print(x+int(w/2),y+int(h/2))
        cv2.imshow("Roi",roi)
        cv2.imshow("main",show)
        
        key = cv2.waitKey(30) #각 frame 마다 30 miliscond
        if key == 27:# esc에 return 값이 27임
            break
            
cap.release()            
cv2.destroyAllWindows()
#contour는 컨투어 정보는 컨투어를 구성하는 점들로 이루어진 배열의 리스트다. 리스트의 원소의 갯수는 컨투어의 갯수와 같다.
# Out:
# 93 133
# 101 139
# 42 82
# 43 83
# 44 88
# 47 95
# 73 119
# 62 80
# 62 85
# 2 81
# 4 108
# 2 98
# 33 133
# 101 148
# 101 148
# 101 149
# 101 150
# 101 154
# 101 155
# 63 88
# 9 105
# 66 92
# 67 92
# 65 92
# 67 94
# 68 93
# 72 92
# 74 93
# 76 93
# 72 92
# 74 93
# 76 93
# 78 92
# 79 92
# 82 93
# 83 93
# 2 87
# 86 94
# 87 94
# 87 94
# 101 138
# 2 134
# 101 137
# 101 137
# 22 112
# 101 137
# 101 138
# 101 138
# 101 139
# 101 140
# 15 108
# 8 87
# 7 87
# 3 141
# 7 87
# 43 134
# 41 132
# 67 90
# 37 128
# 4 89
# 8 107
# 2 82
# 2 99
# 2 99
# 3 96
# 11 94
# 2 82
# 2 79
# 8 87
# 7 123
# 86 139
# 9 123
# 90 137
# 90 134
# 90 132
# 88 131
# 87 127
# 86 124
# 85 123
# 85 125
# 85 126
# 85 128
# 86 128
# 85 129
# 85 129
# 84 129
# 8 121
# 84 127
# 7 121
# 7 121
# 7 121
# 7 120
# 7 121
# 7 121
# 6 120
# 6 120
# 6 120
# 5 120
# 5 120
# 100 140
# 99 138
# 3 98
# 4 121
# 99 138
# 3 98
# 3 99
# 3 98
# 3 98
# 3 97
# 3 98
# 3 100
# 2 103
# 2 102
# 3 102
# 2 100
# 2 101
# 3 102
# 5 122
# 4 100
# 7 92
# ...

# %%
import cv2
import numpy as np
cap = cv2.VideoCapture(0)
while True:
    ret, frame = cap.read() 
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    
    _, threshold = cv2.threshold(gray,40,255,cv2.THRESH_BINARY_INV)
    roiThreshold= threshold[269:795,437:1416]
    
    contours,_ = cv2.findContours(roiThreshold,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)#RETR_TREE는 모두 검출함 & 옛날 꺼가 _,contours,_ 임
    contours = sorted(contours, key=lambda x:cv2.contourArea(x), reverse = True)
    
    #contour중에 둘레가 큰 것만 검출하고 싶어요.ㅜㅜ 제일 큰 사각형 만드는 contour만 뽑을 수 없을 까요?
    #직사각형의 중심 좌표를 구할 수 있는 방법이 있을까요?? 축을 그은 다음에, 그 축의 (x,y)값
    
    if ret:
        roi = frame[269:795,437:1416]
        rows,cols,_ = roi.shape
        print(len(contours))
        print(contours)
        for cnt in contours:
            (x,y,w,h) = cv2.boundingRect(cnt)
            cv2.drawContours(roi,[cnt],-1,(0,0,255),1)
            cv2.rectangle(roi,(x,y),(x+w,y+h),(255,0,0),2)
            cv2.line(roi,(x+int(w/2),0),(x+int(w/2),rows),(0,255,0),2)
            cv2.line(roi,(0,y+int(h/2)),(cols, y+int(h/2)),(0,255,0),2)
            
        cv2.imshow("Roi",roi)
        cv2.imshow("main",threshold[269:795,437:1416])
        
        key = cv2.waitKey(30) #각 frame 마다 30 miliscond
        if key == 27:# esc에 return 값이 27임
            break

cap.release()            
cv2.destroyAllWindows()

# %%
#roi를 따내보자\
import cv2
import numpy as np


cap = cv2.VideoCapture(0)
computerValue = []



while True:
    ret, frame = cap.read() 
    roi = frame
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    _, threshold = cv2.threshold(gray,37,255,cv2.THRESH_BINARY_INV)
    show=cv2.GaussianBlur(threshold,(7,7),0)
    contours,_ = cv2.findContours(show,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)#RETR_TREE는 모두 검출함
    
    contours = sorted(contours, key=lambda x:cv2.contourArea(x), reverse = True)
    if ret:
        rows,cols,_ = roi.shape
        
        #print(len(contours))
        #print(contours)# 리스트의 원소의 갯수는 컨투어의 갯수와 같다.컨투어 정보는 컨투어를 구성하는 점들로 이루어진 배열의 리스트다.
        
        for cnt in contours:
            
            (x,y,w,h) = cv2.boundingRect(cnt)
            
            cv2.drawContours(roi,[cnt],-1,(0,0,255),1)
            cv2.rectangle(roi,(x,y),(x+w,y+h),(255,0,0),1)
            
            #사각형이 너무 많이 잡힘. 가장 큰 사각형만 추출 할 수 있으면,,
            
            cv2.line(roi,(x+int(w/2),0),(x+int(w/2),rows),(0,255,0),2)
            cv2.line(roi,(0,y+int(h/2)),(cols, y+int(h/2)),(0,255,0),2)
             
        print(x+int(w/2),y+int(h/2))
        
        a = x+int(w/2)
        b = y+int(h/2)
        computerValue.append([a,b])
        cv2.imshow("Roi",roi)
        cv2.imshow("main",show)
        
        #computerValue.append(list(x,y))
        key = cv2.waitKey(3000) #각 frame 마다 30 miliscond
        if key == 27:# esc에 return 값이 27임
            break
            
cap.release()            
cv2.destroyAllWindows()

print(computerValue)
#contour는 컨투어 정보는 컨투어를 구성하는 점들로 이루어진 배열의 리스트다. 리스트의 원소의 갯수는 컨투어의 갯수와 같다.


print(average(computerValue))
def average(lst):
    first, second = 0,0
    for k in lst:
        first += k[0]
        second += k[1]
        first_av = first/len(lst)
        second_av = second/len(lst)
    result = [round(first_av,4),round(second_av,4)]
    
    return result

# %%
#main code
import cv2
import numpy as np


cap = cv2.VideoCapture(0)
computerValue = []



while True:
    ret, frame = cap.read() 
    roi = frame
    
    
    rightRoi = frame[250:300,250:300]
    leftRoi = frame[250:300,300:350]
    
    roiGray = cv2.cvtColor(roi,cv2.COLOR_BGR2GRAY)
    rightRoiGray = cv2.cvtColor(rightRoi,cv2.COLOR_BGR2GRAY)
    leftROIGray = cv2.cvtColor(leftRoi,cv2.COLOR_BGR2GRAY)
    
    _, roiThreshold = cv2.threshold(roiGray,37,255,cv2.THRESH_BINARY_INV)
    _, rightThreshold = cv2.threshold(rightRoiGray,37,255,cv2.THRESH_BINARY_INV)
    _, leftThreshold = cv2.threshold(leftROIGray,37,255,cv2.THRESH_BINARY_INV)
    
    blurRoiThreshold = cv2.GaussianBlur(roiThreshold,(7,7),0)
    blurRightThreshold = cv2.GaussianBlur(rightThreshold,(7,7),0)
    blurLeftThreshold = cv2.GaussianBlur(leftThreshold,(7,7),0)
    
    rightContour,_ = cv2.findContours(blurRightThreshold,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    leftContour,_ = cv2.findContours(blurLeftThreshold,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    
    
    if ret:
        rows,cols,_ = roi.shape
        rightRows,rightCols,_ = rightRoi.shape
        leftRows,leftCols,_ = leftRoi.shape
        
        #print(len(contours))
        #print(contours)# 리스트의 원소의 갯수는 컨투어의 갯수와 같다.컨투어 정보는 컨투어를 구성하는 점들로 이루어진 배열의 리스트다.
        
        for rightCnt in rightContour:
            (x_r,y_r,w_r,h_r) = cv2.boundingRect(rightCnt)
            
            cv2.drawContours(rightRoi,[rightCnt],-1,(0,0,255),1)
            cv2.rectangle(rightRoi,(x_r,y_r),(x_r+w_r,y_r+h_r),(255,0,0),1)
            
            cv2.line(rightRoi,(x_r+int(w_r/2),0),(x_r+int(w_r/2),rightRows),(0,255,0),2)
            cv2.line(rightRoi,(0,y_r+int(h_r/2)),(rightCols,y_r+int(h_r/2)),(0,255,0),2)
        
        
        for leftCnt in leftContour:
            (x_l,y_l,w_l,h_l) = cv2.boundingRect(leftCnt)
            
            cv2.drawContours(leftRoi,[leftCnt],-1,(0,0,255),1)
            cv2.rectangle(leftRoi,(x_l,y_l),(x_l+w_l,y_l+h_l),(255,0,0),1)
            
            cv2.line(leftRoi,(x_l+int(w_l/2),0),(x_l+int(w_l/2),leftRows),(0,255,0),2)
            cv2.line(leftRoi,(0,y_l+int(h_l/2)),(leftCols,y_l+int(h_l/2)),(0,255,0),2)
        
        

        cv2.imshow("Roi",roi)
        cv2.imshow("rightEye",rightRoi)
        cv2.imshow("leftEye",leftRoi)
        cv2.imshow("roiBinary",blurRoiThreshold)
        cv2.imshow("rightBinary",blurRightThreshold)
        cv2.imshow("leftBinary",blurLeftThreshold)
        
        
        rightPosition=[x_r+int(w_r/2),y_r+int(h_r/2)]
        leftPosition=[x_l+int(w_l/2),y_l+int(h_l/2)]

        
        key = cv2.waitKey(30) #각 frame 마다 30 miliscond
        if key == 27:# esc에 return 값이 27임
            break
            
cap.release()            
cv2.destroyAllWindows()

print(computerValue)

#sendcode
def average(lst):
    first, second = 0,0
    for k in lst:
        first += k[0]
        second += k[1]
        first_av = first/len(lst)
        second_av = second/len(lst)
    result = [round(first_av,4),round(second_av,4)]    
    return result
writeComputerData = average(computerValue)


while True:
    print(average(computerValue),"가 움직임의 평균값입니다.")
    whether = input("3초간 한개의 객체만 인식 되었나요? y/n ")
    if whether == "y":
        with open("dataFile/computerValue.txt","a") as computers:
            computers.write(writeComputerData)
            break
    elif whether == "n":
        break
    else:
        print("re try")
        continue

# %%
#sendcode
def average(lst):
    first, second = 0,0
    for k in lst:
        first += k[0]
        second += k[1]
        first_av = first/len(lst)
        second_av = second/len(lst)
    result = [round(first_av,4),round(second_av,4)]    
    return result
writeComputerData = average(computerValue)


while True:
    print(average(computerValue),"가 움직임의 평균값입니다.")
    whether = input("3초간 한개의 객체만 인식 되었나요? y/n ")
    if whether == "y":
        with open("dataFile/computerValue.txt","a") as computers:
            computers.write(writeComputerData)
            break
    elif whether == "n":
        break
    else:
        print("re try")
        continue
# Out:
# []
# '\ndef average(lst):\n    first, second = 0,0\n    for k in lst:\n        first += k[0]\n        second += k[1]\n        first_av = first/len(lst)\n        second_av = second/len(lst)\n    result = [round(first_av,4),round(second_av,4)]    \n    return result\nwriteComputerData = average(computerValue)\n\n\nwhile True:\n    print(average(computerValue),"가 움직임의 평균값입니다.")\n    whether = input("3초간 한개의 객체만 인식 되었나요? y/n ")\n    if whether == "y":\n        with open("dataFile/computerValue.txt","a") as computers:\n            computers.write(writeComputerData)\n            break\n    elif whether == "n":\n        break\n    else:\n        print("re try")\n        continue'

# %%
import cv2
import numpy as np


cap = cv2.VideoCapture(0)
computerValue = []



while True:
    ret, frame = cap.read() 
    roi = frame
    rightRoi = frame[:,350:500]
    leftRoi = frame[:,300:400]
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    _, threshold = cv2.threshold(gray,37,255,cv2.THRESH_BINARY_INV)
    show=cv2.GaussianBlur(threshold,(7,7),0)
    contours,_ = cv2.findContours(show,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)#RETR_TREE는 모두 검출함
    
    contours = sorted(contours, key=lambda x:cv2.contourArea(x), reverse = True)
    if ret:
        rows,cols,_ = roi.shape
        
        #print(len(contours))
        #print(contours)# 리스트의 원소의 갯수는 컨투어의 갯수와 같다.컨투어 정보는 컨투어를 구성하는 점들로 이루어진 배열의 리스트다.
        
        max_area = 0
        ci = 0
        for i in range(len(contours)):
            cnt = contours[i]
            area=cv2.contourArea(cnt)
            if(area>max_area):
                max_area =area
                ci = i
        cnt = contours[ci]
        
        (x,y,w,h) = cv2.boundingRect(cnt)    
        cv2.drawContours(roi,[cnt],-1,(0,0,255),1)
        cv2.rectangle(roi,(x,y),(x+w,y+h),(255,0,0),1)
            
        #사각형이 너무 많이 잡힘. 가장 큰 사각형만 추출 할 수 있으면,,
            
        cv2.line(roi,(x+int(w/2),0),(x+int(w/2),rows),(0,255,0),2)
        cv2.line(roi,(0,y+int(h/2)),(cols, y+int(h/2)),(0,255,0),2)
        
        print(x+int(w/2),y+int(h/2))
        
        a = x+int(w/2)
        b = y+int(h/2)
        computerValue.append([a,b])
        cv2.imshow("Roi",roi)
        cv2.imshow("main",show)
        cv2.imshow("rightEye",rightRoi)
        cv2.imshow("leftEye",leftRoi)
        #computerValue.append(list(x,y))
        key = cv2.waitKey(30) #각 frame 마다 30 miliscond
        if key == 27:# esc에 return 값이 27임
            break
            
cap.release()            
cv2.destroyAllWindows()

print(computerValue)
#contour는 컨투어 정보는 컨투어를 구성하는 점들로 이루어진 배열의 리스트다. 리스트의 원소의 갯수는 컨투어의 갯수와 같다.

# %%
import cv2
import numpy as np


cap = cv2.VideoCapture(0)
computerValue = []



while True:
    ret, frame = cap.read() 
    roi = frame
    
    
    rightRoi = frame[250:300,250:300]
    leftRoi = frame[250:300,300:350]
    
    roiGray = cv2.cvtColor(roi,cv2.COLOR_BGR2GRAY)
    rightRoiGray = cv2.cvtColor(rightRoi,cv2.COLOR_BGR2GRAY)
    leftROIGray = cv2.cvtColor(leftRoi,cv2.COLOR_BGR2GRAY)
    
    _, roiThreshold = cv2.threshold(roiGray,37,255,cv2.THRESH_BINARY_INV)
    _, rightThreshold = cv2.threshold(rightRoiGray,37,255,cv2.THRESH_BINARY_INV)
    _, leftThreshold = cv2.threshold(leftROIGray,37,255,cv2.THRESH_BINARY_INV)
    
    blurRoiThreshold = cv2.GaussianBlur(roiThreshold,(7,7),0)
    blurRightThreshold = cv2.GaussianBlur(rightThreshold,(7,7),0)
    blurLeftThreshold = cv2.GaussianBlur(leftThreshold,(7,7),0)
    
    rightContour,_ = cv2.findContours(blurRightThreshold,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    leftContour,_ = cv2.findContours(blurLeftThreshold,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
    
    
    
    
    
    if ret:
        rows,cols,_ = roi.shape
        rightRows,rightCols,_ = rightRoi.shape
        leftRows,leftCols,_ = leftRoi.shape
        
        #print(len(contours))
        #print(contours)# 리스트의 원소의 갯수는 컨투어의 갯수와 같다.컨투어 정보는 컨투어를 구성하는 점들로 이루어진 배열의 리스트다.
        max_area = 0
        ci = 0
        for i in range(len(rightContour)):
            rightCnt = rightContour[i]
            area=cv2.contourArea(rightCnt)
            if(area>max_area):
                    max_area =area
        rightCnt = rightContour[i]
        (x_r,y_r,w_r,h_r) = cv2.boundingRect(rightCnt)
        cv2.drawContours(rightRoi,[rightCnt],-1,(0,0,255),1)
        cv2.rectangle(rightRoi,(x_r,y_r),(x_r+w_r,y_r+h_r),(255,0,0),1)
            
        cv2.line(rightRoi,(x_r+int(w_r/2),0),(x_r+int(w_r/2),rightRows),(0,255,0),2)
        cv2.line(rightRoi,(0,y_r+int(h_r/2)),(rightCols,y_r+int(h_r/2)),(0,255,0),2)
        


        cv2.imshow("Roi",roi)
        cv2.imshow("rightEye",rightRoi)
        cv2.imshow("roiBinary",blurRoiThreshold)
        cv2.imshow("rightBinary",blurRightThreshold)
        
        
        rightPosition=[x_r+int(w_r/2),y_r+int(h_r/2)]

        
        key = cv2.waitKey(30) #각 frame 마다 30 miliscond
        if key == 27:# esc에 return 값이 27임
            break
            
cap.release()            
cv2.destroyAllWindows()

print(computerValue)
#contour는 컨투어 정보는 컨투어를 구성하는 점들로 이루어진 배열의 리스트다. 리스트의 원소의 갯수는 컨투어의 갯수와 같다.
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-beec264db6dc> in <module>
#      49             if(area>max_area):
#      50                     max_area =area
# ---> 51         rightCnt = rightContour[i]
#      52         (x_r,y_r,w_r,h_r) = cv2.boundingRect(rightCnt)
#      53         cv2.drawContours(rightRoi,[rightCnt],-1,(0,0,255),1)
#
# IndexError: list index out of range
